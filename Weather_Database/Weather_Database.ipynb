# %%
# Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests

# Import datetime module
from datetime import datetime

# %%
# Create set of random lat and long combinations
lats= np.random.uniform(low= -90.000, high= 90.000, size=2000)
lngs= np.random.uniform(low =-180.000, high= 180.00, size=2000)
lat_lngs= zip(lats, lngs)
lat_lngs

# %%
# Add lat/lng to list
coordinates= list(lat_lngs)

# %%
# Import citipy
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 760

# %%
# Import API key
from config import weather_api_key

# %%
# Build basic URL for OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create empty list for eather data
city_data=[]

# Print beginning of logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        weather_desc= city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Weather": weather_desc,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

# Loop through all cities in list
for i in range(len(cities)):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50== 0 and i>50):
        set_count +=1
        record_count =1
    # Create endpoint URL wiht each city
    city_url= url+ "&q=" + cities[i]
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | oksfjord
# Processing Record 2 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 1 | tessalit
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | tanout
# Processing Record 6 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 1 | hithadhoo
# Processing Record 8 of Set 1 | avarua
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | khatanga
# Processing Record 11 of Set 1 | bluff
# Processing Record 12 of Set 1 | hilo
# Processing Record 13 of Set 1 | tabory
# Processing Record 14 of Set 1 | pemba
# Processing Record 15 of Set 1 | tura
# Processing Record 16 of Set 1 | shebunino
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | talagang
# Processing Record 19 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | jamestown
# Processing Record 22 of Set 1 | kapaa
# Processing Record 23 of Set 1 | hermanus
# Processing Record 24 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 1 | partenit
# Processing Record 26 of Set 1 | puerto ayora
# Processing Record 27 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 1 | saint-denis
# Processing Record 29 of Set 1 | butaritari
# Processing Record 30 of Set 1 | eyl
# Processing Record 31 of Set 1 | moron
# Processing Record 32 of Set 1 | erenhot
# Processing Record 33 of Set 1 | carnarvon
# Processing Record 34 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 1 | okhotsk
# Processing Record 37 of Set 1 | wasilla
# Processing Record 38 of Set 1 | frydlant
# Processing Record 39 of Set 1 | barrow
# Processing Record 40 of Set 1 | taoudenni
# Processing Record 41 of Set 1 | vaini
# Processing Record 42 of Set 1 | margate
# Processing Record 43 of Set 1 | punta arenas
# Processing Record 44 of Set 1 | torbay
# Processing Record 45 of Set 1 | kiruna
# Processing Record 46 of Set 1 | ghanzi
# Processing Record 47 of Set 1 | miandrivazo
# Processing Record 48 of Set 1 | alzamay
# Processing Record 49 of Set 1 | miri
# Processing Record 50 of Set 1 | qaanaaq
# Processing Record 1 of Set 2 | marrakesh
# Processing Record 2 of Set 2 | kaitangata
# Processing Record 3 of Set 2 | kennett
# Processing Record 4 of Set 2 | isernia
# Processing Record 5 of Set 2 | balmedie
# Processing Record 6 of Set 2 | klaksvik
# Processing Record 7 of Set 2 | port alfred
# Processing Record 8 of Set 2 | kijaba
# City not found. Skipping...
# Processing Record 9 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 10 of Set 2 | new norfolk
# Processing Record 11 of Set 2 | hobart
# Processing Record 12 of Set 2 | soyo
# Processing Record 13 of Set 2 | kalengwa
# Processing Record 14 of Set 2 | saskylakh
# Processing Record 15 of Set 2 | kurumkan
# Processing Record 16 of Set 2 | yellowknife
# Processing Record 17 of Set 2 | pevek
# Processing Record 18 of Set 2 | eldorado
# Processing Record 19 of Set 2 | tarudant
# City not found. Skipping...
# Processing Record 20 of Set 2 | kahului
# Processing Record 21 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 2 | atuona
# Processing Record 23 of Set 2 | samaipata
# Processing Record 24 of Set 2 | nikolskoye
# Processing Record 25 of Set 2 | ahipara
# Processing Record 26 of Set 2 | kavieng
# Processing Record 27 of Set 2 | atambua
# Processing Record 28 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 2 | te anau
# Processing Record 30 of Set 2 | lata
# Processing Record 31 of Set 2 | emerald
# Processing Record 32 of Set 2 | havoysund
# Processing Record 33 of Set 2 | flinders
# Processing Record 34 of Set 2 | goderich
# Processing Record 35 of Set 2 | wawa
# Processing Record 36 of Set 2 | craig
# Processing Record 37 of Set 2 | kasongo-lunda
# Processing Record 38 of Set 2 | longyearbyen
# Processing Record 39 of Set 2 | ambulu
# Processing Record 40 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 41 of Set 2 | bethel
# Processing Record 42 of Set 2 | pak chong
# Processing Record 43 of Set 2 | bredasdorp
# Processing Record 44 of Set 2 | roebourne
# Processing Record 45 of Set 2 | saint-philippe
# Processing Record 46 of Set 2 | harboore
# Processing Record 47 of Set 2 | husavik
# Processing Record 48 of Set 2 | itoman
# Processing Record 49 of Set 2 | ponta do sol
# Processing Record 50 of Set 2 | cidreira
# Processing Record 1 of Set 3 | iqaluit
# Processing Record 2 of Set 3 | porto walter
# Processing Record 3 of Set 3 | dikson
# Processing Record 4 of Set 3 | ciudad guayana
# Processing Record 5 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 6 of Set 3 | itaituba
# Processing Record 7 of Set 3 | portland
# Processing Record 8 of Set 3 | mahon
# Processing Record 9 of Set 3 | mar del plata
# Processing Record 10 of Set 3 | narsaq
# Processing Record 11 of Set 3 | kawalu
# Processing Record 12 of Set 3 | varnamo
# Processing Record 13 of Set 3 | albany
# Processing Record 14 of Set 3 | fort payne
# Processing Record 15 of Set 3 | kyra
# Processing Record 16 of Set 3 | biskamzha
# Processing Record 17 of Set 3 | east london
# Processing Record 18 of Set 3 | poso
# Processing Record 19 of Set 3 | merauke
# Processing Record 20 of Set 3 | fortuna
# Processing Record 21 of Set 3 | aklavik
# Processing Record 22 of Set 3 | constitucion
# Processing Record 23 of Set 3 | bengkulu
# Processing Record 24 of Set 3 | ribas do rio pardo
# Processing Record 25 of Set 3 | vredendal
# Processing Record 26 of Set 3 | ituni
# City not found. Skipping...
# Processing Record 27 of Set 3 | nanhai
# Processing Record 28 of Set 3 | fare
# Processing Record 29 of Set 3 | kalininsk
# Processing Record 30 of Set 3 | sao filipe
# Processing Record 31 of Set 3 | chumikan
# Processing Record 32 of Set 3 | rawson
# Processing Record 33 of Set 3 | nantucket
# Processing Record 34 of Set 3 | kavaratti
# Processing Record 35 of Set 3 | zhangye
# Processing Record 36 of Set 3 | verkhnevilyuysk
# Processing Record 37 of Set 3 | huicheng
# Processing Record 38 of Set 3 | kathu
# Processing Record 39 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 3 | yabelo
# Processing Record 41 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 3 | wajir
# Processing Record 43 of Set 3 | saldanha
# Processing Record 44 of Set 3 | santa rosa
# Processing Record 45 of Set 3 | buriti
# Processing Record 46 of Set 3 | lavrentiya
# Processing Record 47 of Set 3 | mendahara
# City not found. Skipping...
# Processing Record 48 of Set 3 | coihaique
# Processing Record 49 of Set 3 | victoria
# Processing Record 50 of Set 3 | sadiqabad
# Processing Record 1 of Set 4 | bilibino
# Processing Record 2 of Set 4 | snezhnogorsk
# Processing Record 3 of Set 4 | sakakah
# Processing Record 4 of Set 4 | mapiri
# Processing Record 5 of Set 4 | tuktoyaktuk
# Processing Record 6 of Set 4 | bom jardim
# Processing Record 7 of Set 4 | plastun
# Processing Record 8 of Set 4 | kodinar
# Processing Record 9 of Set 4 | kodiak
# Processing Record 10 of Set 4 | paamiut
# Processing Record 11 of Set 4 | we
# City not found. Skipping...
# Processing Record 12 of Set 4 | chachapoyas
# Processing Record 13 of Set 4 | cherskiy
# Processing Record 14 of Set 4 | lekoni
# Processing Record 15 of Set 4 | touros
# Processing Record 16 of Set 4 | labrea
# Processing Record 17 of Set 4 | grindavik
# Processing Record 18 of Set 4 | yongan
# Processing Record 19 of Set 4 | ossora
# Processing Record 20 of Set 4 | tabuk
# Processing Record 21 of Set 4 | kuito
# Processing Record 22 of Set 4 | sitka
# Processing Record 23 of Set 4 | qaqortoq
# Processing Record 24 of Set 4 | palmer
# Processing Record 25 of Set 4 | clyde river
# Processing Record 26 of Set 4 | nemuro
# Processing Record 27 of Set 4 | sao joao da barra
# Processing Record 28 of Set 4 | cape town
# Processing Record 29 of Set 4 | salsk
# Processing Record 30 of Set 4 | provideniya
# Processing Record 31 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 4 | makokou
# Processing Record 33 of Set 4 | aksay
# Processing Record 34 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 4 | ranong
# Processing Record 36 of Set 4 | pital
# Processing Record 37 of Set 4 | arraial do cabo
# Processing Record 38 of Set 4 | penzance
# Processing Record 39 of Set 4 | dwarka
# Processing Record 40 of Set 4 | hamilton
# Processing Record 41 of Set 4 | nakamura
# Processing Record 42 of Set 4 | katakwi
# Processing Record 43 of Set 4 | jumla
# Processing Record 44 of Set 4 | calabozo
# Processing Record 45 of Set 4 | huilong
# Processing Record 46 of Set 4 | durango
# Processing Record 47 of Set 4 | bomet
# Processing Record 48 of Set 4 | castro
# Processing Record 49 of Set 4 | kuryk
# Processing Record 50 of Set 4 | feijo
# Processing Record 1 of Set 5 | teahupoo
# Processing Record 2 of Set 5 | sauk rapids
# Processing Record 3 of Set 5 | kelvington
# Processing Record 4 of Set 5 | laguna
# Processing Record 5 of Set 5 | kieta
# Processing Record 6 of Set 5 | north adams
# Processing Record 7 of Set 5 | norman wells
# Processing Record 8 of Set 5 | solovetskiy
# City not found. Skipping...
# Processing Record 9 of Set 5 | atar
# Processing Record 10 of Set 5 | mandera
# Processing Record 11 of Set 5 | chicama
# Processing Record 12 of Set 5 | iisaku
# Processing Record 13 of Set 5 | asau
# Processing Record 14 of Set 5 | ibaiti
# Processing Record 15 of Set 5 | tutoia
# Processing Record 16 of Set 5 | grenville
# Processing Record 17 of Set 5 | pelym
# Processing Record 18 of Set 5 | velez-malaga
# Processing Record 19 of Set 5 | necochea
# Processing Record 20 of Set 5 | lakatoro
# Processing Record 21 of Set 5 | salalah
# Processing Record 22 of Set 5 | upernavik
# Processing Record 23 of Set 5 | sidi ali
# Processing Record 24 of Set 5 | lorengau
# Processing Record 25 of Set 5 | pokanayevka
# City not found. Skipping...
# Processing Record 26 of Set 5 | beisfjord
# Processing Record 27 of Set 5 | mae hong son
# Processing Record 28 of Set 5 | poum
# Processing Record 29 of Set 5 | male
# Processing Record 30 of Set 5 | kidal
# Processing Record 31 of Set 5 | beloha
# Processing Record 32 of Set 5 | faanui
# Processing Record 33 of Set 5 | carutapera
# Processing Record 34 of Set 5 | santa isabel do rio negro
# Processing Record 35 of Set 5 | goure
# Processing Record 36 of Set 5 | mumbwa
# Processing Record 37 of Set 5 | ust-koksa
# Processing Record 38 of Set 5 | lebu
# Processing Record 39 of Set 5 | souillac
# Processing Record 40 of Set 5 | vestmannaeyjar
# Processing Record 41 of Set 5 | saint-louis
# Processing Record 42 of Set 5 | anadyr
# Processing Record 43 of Set 5 | beringovskiy
# Processing Record 44 of Set 5 | geraldton
# Processing Record 45 of Set 5 | bathsheba
# Processing Record 46 of Set 5 | tiksi
# Processing Record 47 of Set 5 | georgetown
# Processing Record 48 of Set 5 | cabo san lucas
# Processing Record 49 of Set 5 | hofn
# Processing Record 50 of Set 5 | salinas
# Processing Record 1 of Set 6 | ilulissat
# Processing Record 2 of Set 6 | dajal
# Processing Record 3 of Set 6 | havre-saint-pierre
# Processing Record 4 of Set 6 | weihai
# Processing Record 5 of Set 6 | chupa
# Processing Record 6 of Set 6 | luderitz
# Processing Record 7 of Set 6 | tuy hoa
# Processing Record 8 of Set 6 | abha
# Processing Record 9 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 10 of Set 6 | guerrero negro
# Processing Record 11 of Set 6 | manzil salim
# Processing Record 12 of Set 6 | deep river
# Processing Record 13 of Set 6 | mahebourg
# Processing Record 14 of Set 6 | cockburn town
# Processing Record 15 of Set 6 | furano
# Processing Record 16 of Set 6 | krasnyy chikoy
# Processing Record 17 of Set 6 | apaxtla
# City not found. Skipping...
# Processing Record 18 of Set 6 | solano
# Processing Record 19 of Set 6 | bad bevensen
# Processing Record 20 of Set 6 | chokurdakh
# Processing Record 21 of Set 6 | pedernales
# Processing Record 22 of Set 6 | tasiilaq
# Processing Record 23 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 6 | bandarbeyla
# Processing Record 25 of Set 6 | gramsh
# Processing Record 26 of Set 6 | launceston
# Processing Record 27 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 6 | bambous virieux
# Processing Record 29 of Set 6 | yomou
# Processing Record 30 of Set 6 | airai
# Processing Record 31 of Set 6 | awjilah
# Processing Record 32 of Set 6 | mwinilunga
# Processing Record 33 of Set 6 | montevideo
# Processing Record 34 of Set 6 | baoshan
# Processing Record 35 of Set 6 | taltal
# Processing Record 36 of Set 6 | acapulco
# Processing Record 37 of Set 6 | sawakin
# Processing Record 38 of Set 6 | deputatskiy
# Processing Record 39 of Set 6 | chilca
# Processing Record 40 of Set 6 | asosa
# Processing Record 41 of Set 6 | thompson
# Processing Record 42 of Set 6 | la rioja
# Processing Record 43 of Set 6 | praia da vitoria
# Processing Record 44 of Set 6 | portpatrick
# City not found. Skipping...
# Processing Record 45 of Set 6 | abu samrah
# Processing Record 46 of Set 6 | dakar
# Processing Record 47 of Set 6 | mount gambier
# Processing Record 48 of Set 6 | oktyabrskiy
# Processing Record 49 of Set 6 | takapau
# Processing Record 50 of Set 6 | tuatapere
# Processing Record 1 of Set 7 | mount isa
# Processing Record 2 of Set 7 | port blair
# Processing Record 3 of Set 7 | aranos
# Processing Record 4 of Set 7 | alyangula
# Processing Record 5 of Set 7 | san patricio
# Processing Record 6 of Set 7 | port elizabeth
# Processing Record 7 of Set 7 | severo-kurilsk
# Processing Record 8 of Set 7 | ixtapa
# Processing Record 9 of Set 7 | alekseyevsk
# Processing Record 10 of Set 7 | porto novo
# Processing Record 11 of Set 7 | half moon bay
# Processing Record 12 of Set 7 | nueva loja
# Processing Record 13 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 14 of Set 7 | mlonggo
# Processing Record 15 of Set 7 | taunggyi
# Processing Record 16 of Set 7 | isangel
# Processing Record 17 of Set 7 | muriwai beach
# Processing Record 18 of Set 7 | dongsheng
# Processing Record 19 of Set 7 | naryan-mar
# Processing Record 20 of Set 7 | siderno
# Processing Record 21 of Set 7 | basoko
# Processing Record 22 of Set 7 | bykov
# Processing Record 23 of Set 7 | takaka
# Processing Record 24 of Set 7 | puerto maldonado
# Processing Record 25 of Set 7 | paranhos
# Processing Record 26 of Set 7 | chernyanka
# Processing Record 27 of Set 7 | vygonichi
# Processing Record 28 of Set 7 | kholtoson
# Processing Record 29 of Set 7 | morondava
# Processing Record 30 of Set 7 | thaba-tseka
# Processing Record 31 of Set 7 | malanje
# Processing Record 32 of Set 7 | lhokseumawe
# Processing Record 33 of Set 7 | inhambane
# Processing Record 34 of Set 7 | angoram
# Processing Record 35 of Set 7 | isla aguada
# Processing Record 36 of Set 7 | konskie
# Processing Record 37 of Set 7 | semirom
# Processing Record 38 of Set 7 | sobolevo
# Processing Record 39 of Set 7 | champerico
# Processing Record 40 of Set 7 | kaeo
# Processing Record 41 of Set 7 | kirakira
# Processing Record 42 of Set 7 | surt
# Processing Record 43 of Set 7 | tuggurt
# City not found. Skipping...
# Processing Record 44 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 45 of Set 7 | noumea
# Processing Record 46 of Set 7 | port shepstone
# Processing Record 47 of Set 7 | ouallam
# Processing Record 48 of Set 7 | copiapo
# Processing Record 49 of Set 7 | lloydminster
# Processing Record 50 of Set 7 | luangwa
# Processing Record 1 of Set 8 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 2 of Set 8 | akdepe
# Processing Record 3 of Set 8 | makambako
# Processing Record 4 of Set 8 | eskasem
# City not found. Skipping...
# Processing Record 5 of Set 8 | oranjestad
# Processing Record 6 of Set 8 | yerbogachen
# Processing Record 7 of Set 8 | dalbandin
# Processing Record 8 of Set 8 | inuvik
# Processing Record 9 of Set 8 | mikhaylovsk
# Processing Record 10 of Set 8 | ancud
# Processing Record 11 of Set 8 | benguela
# Processing Record 12 of Set 8 | bongandanga
# Processing Record 13 of Set 8 | xiongzhou
# Processing Record 14 of Set 8 | maykain
# City not found. Skipping...
# Processing Record 15 of Set 8 | esperance
# Processing Record 16 of Set 8 | zhob
# Processing Record 17 of Set 8 | ambilobe
# Processing Record 18 of Set 8 | mahajanga
# Processing Record 19 of Set 8 | hitchin
# Processing Record 20 of Set 8 | tual
# Processing Record 21 of Set 8 | pangnirtung
# Processing Record 22 of Set 8 | lompoc
# Processing Record 23 of Set 8 | sorong
# Processing Record 24 of Set 8 | timizart
# Processing Record 25 of Set 8 | marsh harbour
# Processing Record 26 of Set 8 | tigil
# Processing Record 27 of Set 8 | tevaitoa
# Processing Record 28 of Set 8 | den helder
# Processing Record 29 of Set 8 | burica
# City not found. Skipping...
# Processing Record 30 of Set 8 | mezen
# Processing Record 31 of Set 8 | oriximina
# Processing Record 32 of Set 8 | kenora
# Processing Record 33 of Set 8 | baykit
# Processing Record 34 of Set 8 | jiaojiang
# Processing Record 35 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 36 of Set 8 | prince george
# Processing Record 37 of Set 8 | mayo
# Processing Record 38 of Set 8 | nagato
# Processing Record 39 of Set 8 | zeya
# Processing Record 40 of Set 8 | eureka
# Processing Record 41 of Set 8 | karakendzha
# City not found. Skipping...
# Processing Record 42 of Set 8 | ukiah
# Processing Record 43 of Set 8 | puerto padre
# Processing Record 44 of Set 8 | coquimbo
# Processing Record 45 of Set 8 | kruisfontein
# Processing Record 46 of Set 8 | katsuura
# Processing Record 47 of Set 8 | pangody
# Processing Record 48 of Set 8 | nome
# Processing Record 49 of Set 8 | lichtenburg
# Processing Record 50 of Set 8 | zyryanovsk
# Processing Record 1 of Set 9 | lowestoft
# Processing Record 2 of Set 9 | nizwa
# Processing Record 3 of Set 9 | lensk
# Processing Record 4 of Set 9 | lasa
# Processing Record 5 of Set 9 | north platte
# Processing Record 6 of Set 9 | road town
# Processing Record 7 of Set 9 | kindu
# Processing Record 8 of Set 9 | staritsa
# Processing Record 9 of Set 9 | vila franca do campo
# Processing Record 10 of Set 9 | linxia
# Processing Record 11 of Set 9 | anloga
# Processing Record 12 of Set 9 | blackwater
# Processing Record 13 of Set 9 | lebyazhye
# Processing Record 14 of Set 9 | alta
# Processing Record 15 of Set 9 | codrington
# Processing Record 16 of Set 9 | port hedland
# Processing Record 17 of Set 9 | rio gallegos
# Processing Record 18 of Set 9 | salinopolis
# Processing Record 19 of Set 9 | balimo
# City not found. Skipping...
# Processing Record 20 of Set 9 | bayan
# Processing Record 21 of Set 9 | maues
# Processing Record 22 of Set 9 | sagana
# Processing Record 23 of Set 9 | lubango
# Processing Record 24 of Set 9 | qinggang
# Processing Record 25 of Set 9 | sanandaj
# Processing Record 26 of Set 9 | jalu
# Processing Record 27 of Set 9 | piedra gorda
# Processing Record 28 of Set 9 | kaspiyskiy
# Processing Record 29 of Set 9 | sokolka
# Processing Record 30 of Set 9 | itamaraju
# Processing Record 31 of Set 9 | probolinggo
# Processing Record 32 of Set 9 | maniitsoq
# Processing Record 33 of Set 9 | truth or consequences
# Processing Record 34 of Set 9 | tena
# Processing Record 35 of Set 9 | mehamn
# Processing Record 36 of Set 9 | naro moru
# Processing Record 37 of Set 9 | takoradi
# Processing Record 38 of Set 9 | vostok
# Processing Record 39 of Set 9 | si bun ruang
# Processing Record 40 of Set 9 | belmonte
# Processing Record 41 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 42 of Set 9 | innisfail
# Processing Record 43 of Set 9 | kibre mengist
# Processing Record 44 of Set 9 | sorkjosen
# Processing Record 45 of Set 9 | turukhansk
# Processing Record 46 of Set 9 | newport
# Processing Record 47 of Set 9 | carballo
# Processing Record 48 of Set 9 | nador
# Processing Record 49 of Set 9 | ariogala
# Processing Record 50 of Set 9 | komyshnya
# Processing Record 1 of Set 10 | morgan city
# Processing Record 2 of Set 10 | mareeba
# Processing Record 3 of Set 10 | sioux lookout
# Processing Record 4 of Set 10 | filadelfia
# Processing Record 5 of Set 10 | arlit
# Processing Record 6 of Set 10 | andenes
# Processing Record 7 of Set 10 | cizre
# Processing Record 8 of Set 10 | leningradskiy
# Processing Record 9 of Set 10 | alta floresta
# Processing Record 10 of Set 10 | barranca
# Processing Record 11 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 10 | darhan
# Processing Record 13 of Set 10 | dhidhdhoo
# Processing Record 14 of Set 10 | whyalla
# Processing Record 15 of Set 10 | phalodi
# Processing Record 16 of Set 10 | cumaribo
# City not found. Skipping...
# Processing Record 17 of Set 10 | nha trang
# Processing Record 18 of Set 10 | moree
# Processing Record 19 of Set 10 | arman
# Processing Record 20 of Set 10 | komsomolskiy
# Processing Record 21 of Set 10 | zhigansk
# Processing Record 22 of Set 10 | parrita
# Processing Record 23 of Set 10 | meulaboh
# Processing Record 24 of Set 10 | boa vista
# Processing Record 25 of Set 10 | siloam springs
# Processing Record 26 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 27 of Set 10 | casper
# Processing Record 28 of Set 10 | tongliao
# Processing Record 29 of Set 10 | oistins
# Processing Record 30 of Set 10 | teknaf
# Processing Record 31 of Set 10 | vanimo
# Processing Record 32 of Set 10 | keetmanshoop
# Processing Record 33 of Set 10 | florianopolis
# Processing Record 34 of Set 10 | la jutosa
# Processing Record 35 of Set 10 | zheleznodorozhnyy
# Processing Record 36 of Set 10 | tungkang
# City not found. Skipping...
# Processing Record 37 of Set 10 | westerland
# Processing Record 38 of Set 10 | lac du bonnet
# Processing Record 39 of Set 10 | yumen
# Processing Record 40 of Set 10 | nishihara
# Processing Record 41 of Set 10 | afanasyevo
# City not found. Skipping...
# Processing Record 42 of Set 10 | centerville
# Processing Record 43 of Set 10 | iracoubo
# Processing Record 44 of Set 10 | makat
# Processing Record 45 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 46 of Set 10 | russell
# Processing Record 47 of Set 10 | vilyuysk
# Processing Record 48 of Set 10 | chuy
# Processing Record 49 of Set 10 | williams lake
# Processing Record 50 of Set 10 | cap malheureux
# Processing Record 1 of Set 11 | fereydun kenar
# Processing Record 2 of Set 11 | sorland
# Processing Record 3 of Set 11 | dicabisagan
# Processing Record 4 of Set 11 | mestia
# Processing Record 5 of Set 11 | pychas
# Processing Record 6 of Set 11 | gat
# Processing Record 7 of Set 11 | inongo
# Processing Record 8 of Set 11 | paramonga
# Processing Record 9 of Set 11 | sao gabriel da cachoeira
# Processing Record 10 of Set 11 | kutum
# Processing Record 11 of Set 11 | harper
# Processing Record 12 of Set 11 | kincardine
# Processing Record 13 of Set 11 | basco
# Processing Record 14 of Set 11 | cape elizabeth
# City not found. Skipping...
# Processing Record 15 of Set 11 | sept-iles
# Processing Record 16 of Set 11 | ternate
# Processing Record 17 of Set 11 | burgeo
# Processing Record 18 of Set 11 | sao paulo de olivenca
# Processing Record 19 of Set 11 | boyolangu
# Processing Record 20 of Set 11 | richards bay
# Processing Record 21 of Set 11 | verkhneyarkeyevo
# Processing Record 22 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 23 of Set 11 | itarema
# Processing Record 24 of Set 11 | honningsvag
# Processing Record 25 of Set 11 | saint-augustin
# Processing Record 26 of Set 11 | dzilam gonzalez
# Processing Record 27 of Set 11 | labuhan
# Processing Record 28 of Set 11 | oranjemund
# Processing Record 29 of Set 11 | vallenar
# Processing Record 30 of Set 11 | ribeira grande
# Processing Record 31 of Set 11 | san cristobal
# Processing Record 32 of Set 11 | avera
# Processing Record 33 of Set 11 | usta muhammad
# Processing Record 34 of Set 11 | dingle
# Processing Record 35 of Set 11 | port hawkesbury
# Processing Record 36 of Set 11 | los cedrales
# Processing Record 37 of Set 11 | trairi
# Processing Record 38 of Set 11 | sofiysk
# City not found. Skipping...
# Processing Record 39 of Set 11 | saint-joseph
# Processing Record 40 of Set 11 | umm lajj
# Processing Record 41 of Set 11 | port lincoln
# Processing Record 42 of Set 11 | hami
# Processing Record 43 of Set 11 | acari
# Processing Record 44 of Set 11 | kalmunai
# Processing Record 45 of Set 11 | pemangkat
# Processing Record 46 of Set 11 | esna
# Processing Record 47 of Set 11 | knysna
# Processing Record 48 of Set 11 | saint george
# Processing Record 49 of Set 11 | yarmouth
# Processing Record 50 of Set 11 | lubao
# Processing Record 1 of Set 12 | altay
# Processing Record 2 of Set 12 | green river
# Processing Record 3 of Set 12 | tome-acu
# City not found. Skipping...
# Processing Record 4 of Set 12 | broken hill
# Processing Record 5 of Set 12 | kabare
# Processing Record 6 of Set 12 | cordele
# Processing Record 7 of Set 12 | katangli
# Processing Record 8 of Set 12 | prabumulih
# Processing Record 9 of Set 12 | vao
# Processing Record 10 of Set 12 | sur
# Processing Record 11 of Set 12 | zhezkazgan
# Processing Record 12 of Set 12 | cayenne
# Processing Record 13 of Set 12 | starosubkhangulovo
# Processing Record 14 of Set 12 | bose
# Processing Record 15 of Set 12 | marawi
# Processing Record 16 of Set 12 | namibe
# Processing Record 17 of Set 12 | nicoya
# Processing Record 18 of Set 12 | alihe
# Processing Record 19 of Set 12 | haskovo
# Processing Record 20 of Set 12 | ostrovnoy
# Processing Record 21 of Set 12 | verkhnyaya inta
# Processing Record 22 of Set 12 | manchester
# Processing Record 23 of Set 12 | rodrigues alves
# Processing Record 24 of Set 12 | ola
# Processing Record 25 of Set 12 | surgut
# Processing Record 26 of Set 12 | pavelets
# Processing Record 27 of Set 12 | keroka
# Processing Record 28 of Set 12 | ostashkov
# Processing Record 29 of Set 12 | kupang
# Processing Record 30 of Set 12 | fulitun
# City not found. Skipping...
# Processing Record 31 of Set 12 | porto velho
# Processing Record 32 of Set 12 | berlevag
# Processing Record 33 of Set 12 | vila velha
# Processing Record 34 of Set 12 | ati
# Processing Record 35 of Set 12 | bilma
# Processing Record 36 of Set 12 | auki
# Processing Record 37 of Set 12 | pisco
# Processing Record 38 of Set 12 | antalaha
# Processing Record 39 of Set 12 | scottsbluff
# Processing Record 40 of Set 12 | faya
# Processing Record 41 of Set 12 | cache creek
# Processing Record 42 of Set 12 | praia
# Processing Record 43 of Set 12 | puerto escondido
# Processing Record 44 of Set 12 | nalut
# Processing Record 45 of Set 12 | nola
# Processing Record 46 of Set 12 | sabattus
# Processing Record 47 of Set 12 | kanniyakumari
# Processing Record 48 of Set 12 | kurilsk
# Processing Record 49 of Set 12 | tocopilla
# Processing Record 50 of Set 12 | leh
# Processing Record 1 of Set 13 | smithers
# Processing Record 2 of Set 13 | erezee
# Processing Record 3 of Set 13 | prince rupert
# Processing Record 4 of Set 13 | janauba
# Processing Record 5 of Set 13 | charlestown
# Processing Record 6 of Set 13 | wonthaggi
# Processing Record 7 of Set 13 | galveston
# Processing Record 8 of Set 13 | varghis
# Processing Record 9 of Set 13 | tyrma
# Processing Record 10 of Set 13 | kloulklubed
# Processing Record 11 of Set 13 | naze
# Processing Record 12 of Set 13 | sinnamary
# Processing Record 13 of Set 13 | roma
# Processing Record 14 of Set 13 | ayagoz
# Processing Record 15 of Set 13 | humaita
# Processing Record 16 of Set 13 | balaka
# Processing Record 17 of Set 13 | hasaki
# Processing Record 18 of Set 13 | sao miguel do araguaia
# Processing Record 19 of Set 13 | hokitika
# Processing Record 20 of Set 13 | kajaani
# Processing Record 21 of Set 13 | wangou
# Processing Record 22 of Set 13 | havelock
# Processing Record 23 of Set 13 | gryfice
# Processing Record 24 of Set 13 | vila
# Processing Record 25 of Set 13 | kropotkin
# Processing Record 26 of Set 13 | villazon
# Processing Record 27 of Set 13 | cabedelo
# Processing Record 28 of Set 13 | chimbote
# Processing Record 29 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 13 | ayan
# Processing Record 31 of Set 13 | burghausen
# Processing Record 32 of Set 13 | tabukiniberu
# City not found. Skipping...
# Processing Record 33 of Set 13 | viedma
# Processing Record 34 of Set 13 | kita
# Processing Record 35 of Set 13 | nanortalik
# Processing Record 36 of Set 13 | hambantota
# Processing Record 37 of Set 13 | rovaniemi
# Processing Record 38 of Set 13 | rincon
# Processing Record 39 of Set 13 | ugoofaaru
# Processing Record 40 of Set 13 | tsienyane
# City not found. Skipping...
# Processing Record 41 of Set 13 | padang
# Processing Record 42 of Set 13 | lola
# Processing Record 43 of Set 13 | adrar
# Processing Record 44 of Set 13 | domoni
# Processing Record 45 of Set 13 | port-cartier
# Processing Record 46 of Set 13 | zvishavane
# Processing Record 47 of Set 13 | tatvan
# Processing Record 48 of Set 13 | oud-beijerland
# Processing Record 49 of Set 13 | beni mazar
# Processing Record 50 of Set 13 | sabang
# Processing Record 1 of Set 14 | baley
# Processing Record 2 of Set 14 | christchurch
# Processing Record 3 of Set 14 | ocampo
# Processing Record 4 of Set 14 | redcliffe
# Processing Record 5 of Set 14 | vardo
# Processing Record 6 of Set 14 | safford
# Processing Record 7 of Set 14 | gardez
# Processing Record 8 of Set 14 | planadas
# Processing Record 9 of Set 14 | rakitnoye
# Processing Record 10 of Set 14 | manuk mangkaw
# Processing Record 11 of Set 14 | fernley
# Processing Record 12 of Set 14 | nadym
# Processing Record 13 of Set 14 | camapua
# Processing Record 14 of Set 14 | alice springs
# Processing Record 15 of Set 14 | wajima
# Processing Record 16 of Set 14 | tomatlan
# Processing Record 17 of Set 14 | kenai
# Processing Record 18 of Set 14 | sambava
# Processing Record 19 of Set 14 | namtsy
# Processing Record 20 of Set 14 | araouane
# Processing Record 21 of Set 14 | puerto narino
# Processing Record 22 of Set 14 | mogadishu
# Processing Record 23 of Set 14 | safaga
# Processing Record 24 of Set 14 | penjamo
# Processing Record 25 of Set 14 | kardla
# Processing Record 26 of Set 14 | zhangjiakou
# Processing Record 27 of Set 14 | waipawa
# Processing Record 28 of Set 14 | parker
# Processing Record 29 of Set 14 | manta
# Processing Record 30 of Set 14 | kiunga
# Processing Record 31 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 32 of Set 14 | yushala
# Processing Record 33 of Set 14 | hvolsvollur
# Processing Record 34 of Set 14 | minas
# Processing Record 35 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 36 of Set 14 | butembo
# Processing Record 37 of Set 14 | lima
# Processing Record 38 of Set 14 | bajil
# Processing Record 39 of Set 14 | matameye
# City not found. Skipping...
# Processing Record 40 of Set 14 | angra
# City not found. Skipping...
# Processing Record 41 of Set 14 | fairbanks
# Processing Record 42 of Set 14 | canto do buriti
# Processing Record 43 of Set 14 | boardman
# Processing Record 44 of Set 14 | warrington
# Processing Record 45 of Set 14 | rio grande
# Processing Record 46 of Set 14 | jian
# Processing Record 47 of Set 14 | logan
# Processing Record 48 of Set 14 | escanaba
# Processing Record 49 of Set 14 | cervo
# Processing Record 50 of Set 14 | saint anthony
# Processing Record 1 of Set 15 | abay
# Processing Record 2 of Set 15 | hobyo
# Processing Record 3 of Set 15 | namatanai
# Processing Record 4 of Set 15 | veraval
# Processing Record 5 of Set 15 | abu dhabi
# Processing Record 6 of Set 15 | haileybury
# Processing Record 7 of Set 15 | agropoli
# Processing Record 8 of Set 15 | wenzhou
# Processing Record 9 of Set 15 | zhongshu
# Processing Record 10 of Set 15 | indiaroba
# Processing Record 11 of Set 15 | pitimbu
# Processing Record 12 of Set 15 | asyut
# Processing Record 13 of Set 15 | sola
# Processing Record 14 of Set 15 | kousseri
# Processing Record 15 of Set 15 | bur gabo
# City not found. Skipping...
# Processing Record 16 of Set 15 | kantang
# Processing Record 17 of Set 15 | roald
# Processing Record 18 of Set 15 | hukuntsi
# Processing Record 19 of Set 15 | soe
# Processing Record 20 of Set 15 | nago
# Processing Record 21 of Set 15 | callaguip
# Processing Record 22 of Set 15 | rio bueno
# Processing Record 23 of Set 15 | rio hato
# Processing Record 24 of Set 15 | kaihua
# Processing Record 25 of Set 15 | kushima
# Processing Record 26 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 27 of Set 15 | qarqin
# Processing Record 28 of Set 15 | zhengjiatun
# Processing Record 29 of Set 15 | nkowakowa
# Processing Record 30 of Set 15 | manicore
# Processing Record 31 of Set 15 | kerrville
# Processing Record 32 of Set 15 | the valley
# Processing Record 33 of Set 15 | kishapu
# Processing Record 34 of Set 15 | belomorsk
# Processing Record 35 of Set 15 | loandjili
# Processing Record 36 of Set 15 | seabra
# Processing Record 37 of Set 15 | mogocha
# Processing Record 38 of Set 15 | shitanjing
# Processing Record 39 of Set 15 | abadzekhskaya
# Processing Record 40 of Set 15 | hauterive
# Processing Record 41 of Set 15 | lokosovo
# Processing Record 42 of Set 15 | bambanglipuro
# Processing Record 43 of Set 15 | cortez
# Processing Record 44 of Set 15 | adamantina
# Processing Record 45 of Set 15 | beatrice
# Processing Record 46 of Set 15 | korla
# Processing Record 47 of Set 15 | cambridge
# Processing Record 48 of Set 15 | matara
# Processing Record 49 of Set 15 | garm
# City not found. Skipping...
# Processing Record 50 of Set 15 | pangkalanbuun
# Processing Record 1 of Set 16 | puerto madero
# Processing Record 2 of Set 16 | sosnovo-ozerskoye
# Processing Record 3 of Set 16 | hailey
# Processing Record 4 of Set 16 | batemans bay
# Processing Record 5 of Set 16 | kargasok
# Processing Record 6 of Set 16 | san quintin
# Processing Record 7 of Set 16 | belyy yar
# Processing Record 8 of Set 16 | sinfra
# Processing Record 9 of Set 16 | omboue
# Processing Record 10 of Set 16 | hoquiam
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Create DataFrame
city_data_df=pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City      Lat       Lng  Current Weather  Max Temp  Humidity  \
# 0   Oksfjord  70.2396   22.3479       light snow     27.00        86
# 1   Tessalit  20.1986    1.0114  overcast clouds     68.63        22
# 2    Ushuaia -54.8000  -68.3000    broken clouds     50.00        76
# 3     Tanout  14.9709    8.8879  overcast clouds     58.73        29
# 4  Hithadhoo  -0.6000   73.0833    broken clouds     81.30        75
# 5     Avarua -21.2078 -159.7750       few clouds     86.00        66
# 6  Busselton -33.6500  115.3333       light rain     62.01        95
# 7   Khatanga  71.9667  102.5000        clear sky    -34.62        78
# 8      Bluff -46.6000  168.3333        clear sky     61.45        71
# 9       Hilo  19.7297 -155.0900    broken clouds     78.80        53
#
#    Cloudiness  Wind Speed Country
# 0          90       12.66      NO
# 1         100        8.72      ML
# 2          75       12.66      AR
# 3          86        9.24      NE
# 4          61       12.77      MV
# 5          17       11.50      CK
# 6         100        1.99      AU
# 7           0        8.95      RU
# 8           0        7.96      NZ
# 9          75        5.75      US

# %%
# Reorder columns
new_column_order= ["City", "Country", "Lat", "Lng", "Current Weather", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df= city_data_df[new_column_order]
city_data_df.head()
# Out:
#         City Country      Lat      Lng  Current Weather  Max Temp  Humidity  \
# 0   Oksfjord      NO  70.2396  22.3479       light snow     27.00        86
# 1   Tessalit      ML  20.1986   1.0114  overcast clouds     68.63        22
# 2    Ushuaia      AR -54.8000 -68.3000    broken clouds     50.00        76
# 3     Tanout      NE  14.9709   8.8879  overcast clouds     58.73        29
# 4  Hithadhoo      MV  -0.6000  73.0833    broken clouds     81.30        75
#
#    Cloudiness  Wind Speed
# 0          90       12.66
# 1         100        8.72
# 2          75       12.66
# 3          86        9.24
# 4          61       12.77

# %%
# Create CSV file
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export city_data into CSV
city_data_df.to_csv(output_data_file, index_label= "City_ID")
